# %%
import pandas as pd
import numpy as np


colunas_selecionadas = [
    'Territorialidades',
    'IDHM 1991', 'IDHM 2000', 'IDHM 2010', 
    'IDHM Renda 1991', 'IDHM Renda 2000', 'IDHM Renda 2010', 
    'IDHM Longevidade 1991', 'IDHM Longevidade 2000', 'IDHM Longevidade 2010', 
    'IDHM Educação 1991', 'IDHM Educação 2000', 'IDHM Educação 2010'
]


file_path = '../data/Atlas.xlsx' 
df = pd.read_excel(file_path) 

df_filtrado = df[colunas_selecionadas]

print("--- VISÃO GERAL (APÓS FILTRAGEM) ---")
print(f"Amostras (linhas): {df_filtrado.shape[0]}")
print(f"Atributos (colunas): {df_filtrado.shape[1]}")


print("\n--- TIPOS DE DADOS E VALORES NÃO-NULOS ---")
df_filtrado.info()


print("\n--- VALORES FALTANTES ---")
print(df_filtrado.isnull().sum())
# Out:
# --- VISÃO GERAL (APÓS FILTRAGEM) ---
# Amostras (linhas): 31
# Atributos (colunas): 13
#
# --- TIPOS DE DADOS E VALORES NÃO-NULOS ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Territorialidades      31 non-null     object
#  1   IDHM 1991              29 non-null     object
#  2   IDHM 2000              28 non-null     float64
#  3   IDHM 2010              28 non-null     float64
#  4   IDHM Renda 1991        28 non-null     float64
#  5   IDHM Renda 2000        28 non-null     float64
#  6   IDHM Renda 2010        28 non-null     float64
#  7   IDHM Longevidade 1991  28 non-null     float64
#  8   IDHM Longevidade 2000  28 non-null     float64
#  9   IDHM Longevidade 2010  28 non-null     float64
#  10  IDHM Educação 1991     28 non-null     float64
#  11  IDHM Educação 2000     28 non-null     float64
#  12  IDHM Educação 2010     28 non-null     float64
# dtypes: float64(11), object(2)
# memory usage: 3.3+ KB
#
# --- VALORES FALTANTES ---
# Territorialidades        0
# IDHM 1991                2
# IDHM 2000                3
# IDHM 2010                3
# IDHM Renda 1991          3
# IDHM Renda 2000          3
# IDHM Renda 2010          3
# IDHM Longevidade 1991    3
# IDHM Longevidade 2000    3
# IDHM Longevidade 2010    3
# IDHM Educação 1991       3
# IDHM Educação 2000       3
# IDHM Educação 2010       3
# dtype: int64
